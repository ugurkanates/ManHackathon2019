# %% [markdown]
# ## Exploring the data
# This notebooks helps you to read in the data from the previously mounted storage account and do a display and count on the data. Please note that this is only a quick starting guide to get you started as fast as possible. This notebook doesn't have the purpose to solve the challenges you will face during the hackathon.
# The sections are separated as following:
#
# 1. performancedata
# 2. maintenancedata
# 3. locationdata
# 4. etgmdatalogger
# 5. simbadata
#
# ##### Important: You have to mount the storage accounts before running this notebook by executing the notebook mount.ipynb / mount.dbc

# %% [markdown]
# #### mounting

# %%
dbutils.fs.unmount("/mnt/maintenance-data")
dbutils.fs.mount(
  source = "wasbs://maintenancedata@manhackdata.blob.core.windows.net",
  mount_point = "/mnt/maintenance-data",
  extra_configs = {"fs.azure.sas.maintenancedata.manhackdata.blob.core.windows.net":"?sv=2019-02-02&ss=bfqt&srt=sco&sp=rlacup&se=2019-12-07T23:42:39Z&st=2019-11-27T15:42:39Z&spr=https&sig=hGQZY6fAuS3ZCTJAHu9cK5sftaeJM5njNTCeSYMfZbw%3D"})



df_main = spark.read.parquet("/mnt/maintenance-data/month=*/day=*/hour=*/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/maintenance-data has been unmounted.
# </div>

# %%
import numpy as np
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_main = df_main.select('payloaddecoded_vehiclestate_tire_tirecondition_thresholddetection','payloaddecoded_vehiclestate_tire_tirecondition_pressure','payloaddecoded_header_mileage')#df_main.select('payloaddecoded_vehiclestate_tire_tirecondition_airleakagerate','payloaddecoded_vehiclestate_tire_tirecondition_thresholddetection','payloaddecoded_vehiclestate_tire_tirecondition_pressure','payloaddecoded_vehiclestate_tire_tirecondition_temperature','payloaddecoded_header_mileage')
display(df_main)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#df_main = df_main.filter(df_main.payloaddecoded_vehiclestate_tire_tirecondition_airleakagerate.isNotNull())
df_main = df_main.filter(df_main.payloaddecoded_vehiclestate_tire_tirecondition_thresholddetection. isNotNull())
df_main = df_main.filter(df_main.payloaddecoded_vehiclestate_tire_tirecondition_pressure. isNotNull())
#df_main = df_main.filter(df_main.payloaddecoded_vehiclestate_tire_tirecondition_temperature. isNotNull())
df_main = df_main.filter(df_main.payloaddecoded_header_mileage. isNotNull())

#  gidilen yol as y column = payloaddecoded_header_mileage
# expression stringden inte cevir as input
#display(df_main)
#pandas_df = df2.select("*").toPandas()

#display(pandas_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pandas = df_main.select("*").toPandas()
display(df_pandas)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
test = ["NO_WARNING_PRESSURE","NO_WARNING_PRESSURE","NO_WARNING_PRESSURE","NO_WARNING_PRESSURE","NO_WARNING_PRESSURE","NO_WARNING_PRESSURE"]
import numpy as np
input1 =[]
input2 =[]

for x in df_pandas['payloaddecoded_vehiclestate_tire_tirecondition_thresholddetection']:
  if(np.array_equal(test,x)):
    input1.append(0)
    #print("why")
  else:
    input1.append(1)
for x in df_pandas['payloaddecoded_vehiclestate_tire_tirecondition_pressure']:
  input2.append(np.average(x))
input1np = np.asarray(input1)
input1np = input1np[:15000]

input2np = np.asarray(input2)
input2np = input2np[:15000]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(len(input1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">352769
# </div>

# %%
#mask = np.isnan(output2)
outputReal = df_pandas['payloaddecoded_header_mileage']
outputReal = np.array(outputReal)
outputReal = outputReal[:15000]

import math
j = 0
for x in input1np:
  if math.isnan(x) or math.isinf(x):
    input1np[j] = 0
  j = j+1
  
j = 0
for x in input2np:
  if math.isnan(x) or math.isinf(x):
    input2np[j] = 700
  j = j+1
j = 0
for x in outputReal:
  if math.isnan(x) or math.isinf(x):
    outputReal[j] = 700
  j = j+1
  
#print(output2)

#np.isnan(X_train).any()
#np.isfinite(X_train).any()
#import sys


#np.set_printoptions(threshold=sys.maxsize) shows nan ones.

#print(mask)

#print(output)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2599481508752020&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      7</span> j <span class="ansi-blue-fg">=</span> <span class="ansi-cyan-fg">0</span>
# ...

# %%
newdata = pd.concat([pd.DataFrame(input1np), pd.DataFrame(input2np)], axis=1)
print(input1np.shape)
print(input2np.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(0,)
# (0,)
# </div>

# %%
print(newdata)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Empty DataFrame
# Columns: [0, 0]
# Index: []
# </div>

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

#output direk oluyor mu? yonada mlazmi
X_train, X_test, y_train, y_test = train_test_split(newdata, outputReal, test_size = 1/3, random_state = 0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ValueError</span>                                Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2599481508752011&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>
# <span class="ansi-green-intense-fg ansi-bold">      6</span> <span class="ansi-red-fg">#output direk oluyor mu? yonada mlazmi</span>
# ...

# %%
#delete_for_x = y_train.size
#delete_for_xtest = y_test.size
#X_train = np.delete(X_train,np.arange(delete_for_x,X_train.size,1))
#X_test=np.delete(X_test,np.arange(delete_for_xtest,X_test.size,1))
print(X_test.shape)
print(X_train.shape)
print(y_train.shape)
print(y_test.shape)


print(type(X_test))
print(type(y_test))
print(type(X_train))
print(type(y_test))
print("---------")
print(X_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2599481508752018&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> <span class="ansi-red-fg">#X_train = np.delete(X_train,np.arange(delete_for_x,X_train.size,1))</span>
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()    # This object is the regressor, that does the regression
#X_train = np.array(X_train).reshape((-1,1))
#y_train = np.array(y_train).reshape((-1,1))



regressor.fit(X_train, y_train)   # Provide training data so the machine can learn to predict using a learned model.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2599481508752007&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      6</span>
# <span class="ansi-green-intense-fg ansi-bold">      7</span>
# ...

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#np.isnan(X_train).any()
#np.isfinite(X_train).any()
#X_train = X_train.replace([np.inf, -np.inf], np.mean(X_test))

ysonuc = regressor.predict(X_test)
print(ysonuc[0:15])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2599481508752022&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> <span class="ansi-red-fg">#X_train = X_train.replace([np.inf, -np.inf], np.mean(X_test))</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>
# ...
